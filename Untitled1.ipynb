# %%
data = {
    "code": 200,
    "response": {
        "data": {
            "lead": {
                "activities": "No Physical Activity",
                "addresses": {
                    "default": {
                        "city": "Mumbai",
                        "landmark": "Devi Temple",
                        "pincode": "400050",
                        "state": "Maharashtra",
                        "street": "This is my Address",
                        "street_2": "This is new Address"
                    },
                    "evening_address": {
                        "city": "Mumbai",
                        "landmark": "Devi Temple",
                        "pincode": "400050",
                        "state": "Maharashtra",
                        "street": "This is my Address",
                        "street_2": "This is new Address"
                    },
                    "is_evening_address_same": false,
                    "is_weekend_address_same": false,
                    "is_weekend_evening_address_same": false,
                    "weekend_address": {
                        "city": "Mumbai",
                        "landmark": "Devi Temple",
                        "pincode": "400050",
                        "state": "Maharashtra",
                        "street": "This is my Address",
                        "street_2": "This is new Address"
                    },
                    "weekend_evening_address": {
                        "city": "Mumbai",
                        "landmark": "Devi Temple",
                        "pincode": "400050",
                        "state": "Maharashtra",
                        "street": "This is my Address",
                        "street_2": "This is new Address"
                    }
                },
                "age": 24,
                "body_fat": "Normal",
                "diet": "Ketogenic",
                "doesnt_eat_meat": [
                    "mutton"
                ],
                "dont_eat_egg_on": [
                    "tue"
                ],
                "dont_eat_nonveg_on": [
                    "thu"
                ],
                "egg_in_bread": "Yes",
                "email": "nishil@gmail.com",
                "formatted_iso_start_date": "2022-06-28T23:59:59+05:30",
                "gender": "M",
                "goal": "Lose weight",
                "height_feet": 5,
                "height_inches": 8,
                "last_page": "physical-activities",
                "lead_attempt": {
                    "address_city": "Mumbai",
                    "address_evening_city": "Mumbai",
                    "address_evening_pincode": "400050",
                    "address_evening_state": "Maharashtra",
                    "address_evening_street": "This is my Address",
                    "address_pincode": "400050",
                    "address_state": "Maharashtra",
                    "address_street": "This is my Address",
                    "address_weekend_city": "Mumbai",
                    "address_weekend_evening_city": "Mumbai",
                    "address_weekend_evening_pincode": "400050",
                    "address_weekend_evening_state": "Maharashtra",
                    "address_weekend_evening_street": "This is my Address",
                    "address_weekend_pincode": "400050",
                    "address_weekend_state": "Maharashtra",
                    "address_weekend_street": "This is my Address",
                    "age": 24,
                    "birth_date": null,
                    "body_fat": "Normal",
                    "categories": null,
                    "created_at": "2020-01-19 03:45:46",
                    "cuisine_id": 96,
                    "deleted_at": null,
                    "diet": "Ketogenic",
                    "diet_combo_id": null,
                    "discount_code": null,
                    "discount_code_frontend": null,
                    "doesnt_eat_meat": [
                        "mutton"
                    ],
                    "dont_eat_egg_on": [
                        "tue"
                    ],
                    "dont_eat_nonveg_on": [
                        "thu"
                    ],
                    "egg_in_bread": "Yes",
                    "email": "nishil@gmail.com",
                    "f_b": 0,
                    "f_d": 0,
                    "f_l": 1,
                    "f_md": 0,
                    "f_mm": 0,
                    "f_mn": 0,
                    "first_name": "Nishil",
                    "gender": "M",
                    "goal_id": 1,
                    "goal_text": "Lose weight",
                    "hear_about": null,
                    "height_feet": 5,
                    "height_inches": 8,
                    "id": 23,
                    "last_name": null,
                    "last_page": "physical-activities",
                    "last_step": 7,
                    "lead_id": 30,
                    "meal_plan": "Eggetarian",
                    "meals": [
                        "lunch"
                    ],
                    "menu_type_id": 9,
                    "notes": "I want good food only",
                    "num_days": "30",
                    "payment": null,
                    "payment_method": null,
                    "payment_status": "1",
                    "phone": "9821251304",
                    "physical_activity": "No Physical Activity",
                    "preference": "Doesn't Eat on Tue",
                    "razorpay_json": null,
                    "razorpay_payment_id": null,
                    "s_b": 1,
                    "s_d": 1,
                    "s_l": 0,
                    "s_md": 1,
                    "s_mm": 0,
                    "s_mn": 0,
                    "start_date": "2022-06-28",
                    "tag": null,
                    "target_calories": null,
                    "updated_at": "2022-04-05 17:24:19",
                    "utm_campaign": null,
                    "utm_content": null,
                    "utm_id": null,
                    "utm_medium": null,
                    "utm_source": null,
                    "utm_term": null,
                    "weekend_deliveries": "Y",
                    "weight": "77.00"
                },
                "lead_id": 30,
                "meal_preference": "Eggetarian",
                "meals": [
                    "lunch"
                ],
                "name": "Nishil ",
                "no_of_days": 30,
                "notes": "I want good food only",
                "payment": null,
                "payment_status": 1,
                "phone": "9821251304",
                "razorpay_order_id": null,
                "razorpay_payment_id": null,
                "start_date": "28/06/2022",
                "utm_campaign": null,
                "utm_content": null,
                "utm_id": null,
                "utm_medium": null,
                "utm_source": null,
                "utm_term": null,
                "weekend_deliveries": "Y",
                "weight": 77,
                "whatsapp_consent": 1
            },
            "old_customer": false,
            "old_lead": false
        }
    },
    "success": true
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 data = {
#       2     "code": 200,
#       3     "response": {
#       4         "data": {
#       5             "lead": {
#       6                 "activities": "No Physical Activity",
#       7                 "addresses": {
#       8                     "default": {
#       9                         "city": "Mumbai",
#      10                         "landmark": "Devi Temple",
#      11                         "pincode": "400050",
#      12                         "state": "Maharashtra",
#      13                         "street": "This is my Address",
#      14                         "street_2": "This is new Address"
#      15                     },
#      16                     "evening_address": {
#      17                         "city": "Mumbai",
# ...
